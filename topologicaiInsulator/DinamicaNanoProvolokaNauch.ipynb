# %%
#read evolution in file E=50 кВ/см
tn=2490
f1 = open('CntRenN50_upcontn.txt')
f2 = open('CntImnN50_upcontn.txt')
CnreadRe=[]
CnreadIm=[]
for i in range(tn):
    CnreadRe.append([])
    CnreadIm.append([])
    for j in range(N):
        CnreadRe[i].append(f1.readline().split("\n"))
        CnreadIm[i].append(f2.readline().split("\n"))
Cn50=[]
for i in range(tn):
    Cn50.append([])
    for j in range(N):
        Cn50[i].append(complex(CnreadRe[i][j][0])+1j*complex(CnreadIm[i][j][0]))
f1.close()
f2.close()
# *********************************
# *********************************
#read evolution in file E=40 кВ/см
f1 = open('CntRenN40_upcontn.txt')
f2 = open('CntImnN40_upcontn.txt')
N=2078
CnreadRe=[]
CnreadIm=[]
for i in range(tn):
    CnreadRe.append([])
    CnreadIm.append([])
    for j in range(N):
        CnreadRe[i].append(f1.readline().split("\n"))
        CnreadIm[i].append(f2.readline().split("\n"))
Cn40=[]
for i in range(tn):
    Cn40.append([])
    for j in range(N):
        Cn40[i].append(complex(CnreadRe[i][j][0])+1j*complex(CnreadIm[i][j][0]))
f1.close()
f2.close()
# *********************************
# *********************************
#read evolution in file E=30 кВ/см
f1 = open('CntRenN30_upcontn.txt')
f2 = open('CntImnN30_upcontn.txt')
N=2078
CnreadRe=[]
CnreadIm=[]
for i in range(tn):
    CnreadRe.append([])
    CnreadIm.append([])
    for j in range(N):
        CnreadRe[i].append(f1.readline().split("\n"))
        CnreadIm[i].append(f2.readline().split("\n"))
Cn30=[]
for i in range(tn):
    Cn30.append([])
    for j in range(N):
        Cn30[i].append(complex(CnreadRe[i][j][0])+1j*complex(CnreadIm[i][j][0]))
f1.close()
f2.close()
# *********************************
# *********************************
# read evolution in file E=20 кВ/см
f1 = open('CntRenN20_upcontn.txt')
f2 = open('CntImnN20_upcontn.txt')
N=2078
CnreadRe=[]
CnreadIm=[]
for i in range(tn):
    CnreadRe.append([])
    CnreadIm.append([])
    for j in range(N):
        CnreadRe[i].append(f1.readline().split("\n"))
        CnreadIm[i].append(f2.readline().split("\n"))
Cn20=[]
for i in range(tn):
    Cn20.append([])
    for j in range(N):
        Cn20[i].append(complex(CnreadRe[i][j][0])+1j*complex(CnreadIm[i][j][0]))
f1.close()
f2.close()
# *********************************
# *********************************
# read evolution in file E=80 кВ/см
f1 = open('CntRenN80_upcontn.txt')
f2 = open('CntImnN80_upcontn.txt')
N=2078
CnreadRe=[]
CnreadIm=[]
for i in range(tn):
    CnreadRe.append([])
    CnreadIm.append([])
    for j in range(N):
        CnreadRe[i].append(f1.readline().split("\n"))
        CnreadIm[i].append(f2.readline().split("\n"))
Cn80=[]
for i in range(tn):
    Cn80.append([])
    for j in range(N):
        Cn80[i].append(complex(CnreadRe[i][j][0])+1j*complex(CnreadIm[i][j][0]))
f1.close()
f2.close()

# %%
import numpy as np
fileEn = open("continuum_states.txt")
fileYRe = open("ReYnmDH.dat")
fileYIm = open("ImYnmDH.dat")
fileSxRe = open("ReSx.dat")
#fileSxIm = open("MatrixElemSigmaXnmIm.txt")
fileSyRe = open("MatrixElemSigmaYnmRe.txt")
fileSyIm = open("MatrixElemSigmaYnmIm.txt")
fileSzRe = open("MatrixElemSigmaZnmRe.txt")
fileSzIm = open("MatrixElemSigmaZnmIm.txt")
# *****************************
f1 = open('CntRenN50.txt')
f2 = open('CntImnN50.txt')
tn=2490
N=2078
CnreadRe=[]
CnreadIm=[]
for i in range(tn):
    CnreadRe.append([])
    CnreadIm.append([])
    for j in range(N):
        CnreadRe[i].append(f1.readline())
        CnreadIm[i].append(f2.readline())
Cn50=[]
for i in range(tn):
    Cn50.append([])
    for j in range(N):
        Cn50[i].append(complex(CnreadRe[i][j])+1j*complex(CnreadIm[i][j]))
f1.close()
f2.close()
# *********************************
# *********************************
#read evolution in file E=40 кВ/см
f1 = open('CntRenN40.txt')
f2 = open('CntImnN40.txt')
N=2078
CnreadRe=[]
CnreadIm=[]
for i in range(tn):
    CnreadRe.append([])
    CnreadIm.append([])
    for j in range(N):
        CnreadRe[i].append(f1.readline())
        CnreadIm[i].append(f2.readline())
Cn40=[]
for i in range(tn):
    Cn40.append([])
    for j in range(N):
        Cn40[i].append(complex(CnreadRe[i][j])+1j*complex(CnreadIm[i][j]))
f1.close()
f2.close()
# *********************************
# *********************************
#read evolution in file E=30 кВ/см
f1 = open('CntRenN30.txt')
f2 = open('CntImnN30.txt')
N=2078
CnreadRe=[]
CnreadIm=[]
for i in range(tn):
    CnreadRe.append([])
    CnreadIm.append([])
    for j in range(N):
        CnreadRe[i].append(f1.readline())
        CnreadIm[i].append(f2.readline())
Cn30=[]
for i in range(tn):
    Cn30.append([])
    for j in range(N):
        Cn30[i].append(complex(CnreadRe[i][j])+1j*complex(CnreadIm[i][j]))
f1.close()
f2.close()
# *********************************
# *********************************
# read evolution in file E=20 кВ/см
f1 = open('CntRenN20.txt')
f2 = open('CntImnN20.txt')
N=2078
CnreadRe=[]
CnreadIm=[]
for i in range(tn):
    CnreadRe.append([])
    CnreadIm.append([])
    for j in range(N):
        CnreadRe[i].append(f1.readline())
        CnreadIm[i].append(f2.readline())
Cn20=[]
for i in range(tn):
    Cn20.append([])
    for j in range(N):
        Cn20[i].append(complex(CnreadRe[i][j])+1j*complex(CnreadIm[i][j]))
f1.close()
f2.close()
# *********************************
# *********************************
# read evolution in file E=80 кВ/см
f1 = open('CntRenN80.txt')
f2 = open('CntImnN80.txt')
N=2078
CnreadRe=[]
CnreadIm=[]
for i in range(tn):
    CnreadRe.append([])
    CnreadIm.append([])
    for j in range(N):
        CnreadRe[i].append(f1.readline())
        CnreadIm[i].append(f2.readline())
Cn80=[]
for i in range(tn):
    Cn80.append([])
    for j in range(N):
        Cn80[i].append(complex(CnreadRe[i][j])+1j*complex(CnreadIm[i][j]))
f1.close()
f2.close()

# %%
# 1 state, 2 state E=20 кВ/см
import numpy as np
from numpy import linalg as la
tn=2490
C0_80Fullnew=[]
C0_50Fullnew=[]
C0_40Fullnew=[]
C0_30Fullnew=[]
C0_20Fullnew=[]
C1_80Fullnew=[]
C1_50Fullnew=[]
C1_40Fullnew=[]
C1_30Fullnew=[]
C1_20Fullnew=[]
C0_20=[]    
C1_20=[]
Cnorm_20=[]
tlist = np.linspace(1, tn, tn)
for i in range(tn):
    if ((i+1) % 20) == 0:
        C0_20Fullnew.append(abs(np.conj(Cn20[i][0])*Cn20[i][0]))
        C1_20Fullnew.append(abs(np.conj(Cn20[i][1])*Cn20[i][1]))
    C0_20.append(abs(np.conj(Cn20[i][0])*Cn20[i][0]))
    C1_20.append(abs(np.conj(Cn20[i][1])*Cn20[i][1]))
    Cnorm_20.append(la.norm(Cn20[i], ord=2))
# *********************************
# 1 state, 2 state E=30 кВ/см
import numpy as np
from numpy import linalg as la
C0_30=[]    
C1_30=[]
Cnorm_30=[]
tlist = np.linspace(1, tn, tn)
for i in range(tn):
    if ((i+1) % 20) == 0:
        C0_30Fullnew.append(abs(np.conj(Cn30[i][0])*Cn30[i][0]))
        C1_30Fullnew.append(abs(np.conj(Cn30[i][1])*Cn30[i][1]))
    C0_30.append(abs(np.conj(Cn30[i][0])*Cn30[i][0]))
    C1_30.append(abs(np.conj(Cn30[i][1])*Cn30[i][1]))
    Cnorm_30.append(la.norm(Cn30[i], ord=2))
# *********************************
# 1 state, 2 state E=40 кВ/см
import numpy as np
from numpy import linalg as la
C0_40=[]    
C1_40=[]
Cnorm_40=[]
tlist = np.linspace(1, tn, tn)
for i in range(tn):
    if ((i+1) % 20) == 0:
        C0_40Fullnew.append(abs(np.conj(Cn40[i][0])*Cn40[i][0]))
        C1_40Fullnew.append(abs(np.conj(Cn40[i][1])*Cn40[i][1]))
    C0_40.append(abs(np.conj(Cn40[i][0])*Cn40[i][0]))
    C1_40.append(abs(np.conj(Cn40[i][1])*Cn40[i][1]))
    Cnorm_40.append(la.norm(Cn40[i], ord=2))
# *********************************
# *********************************
# # 1 state, 2 state E=50 кВ/см
C0_50=[]    
C1_50=[]
Cnorm_50=[]
tlist = np.linspace(1, tn, tn)
for i in range(tn):
    if ((i+1) % 20) == 0:
        C0_50Fullnew.append(abs(np.conj(Cn50[i][0])*Cn50[i][0]))
        C1_50Fullnew.append(abs(np.conj(Cn50[i][1])*Cn50[i][1]))
    C0_50.append(abs(np.conj(Cn50[i][0])*Cn50[i][0]))
    C1_50.append(abs(np.conj(Cn50[i][1])*Cn50[i][1]))
    Cnorm_50.append(la.norm(Cn50[i], ord=2))
# *********************************
# *********************************
# # 1 state, 2 state E=50 кВ/см
C0_80=[]    
C1_80=[]
Cnorm_80=[]
tlist = np.linspace(1, tn, tn)
for i in range(tn):
    if ((i+1) % 20) == 0:
        C0_80Fullnew.append(abs(np.conj(Cn80[i][0])*Cn80[i][0]))
        C1_80Fullnew.append(abs(np.conj(Cn80[i][1])*Cn80[i][1]))
    C0_80.append(abs(np.conj(Cn80[i][0])*Cn80[i][0]))
    C1_80.append(abs(np.conj(Cn80[i][1])*Cn80[i][1]))
    Cnorm_80.append(la.norm(Cn80[i], ord=2))

# %%
import matplotlib.pyplot as plt
import pylab
pylab.plot (tlist, Cnorm_20)
plt.ylim(0, 1.2)
# Out:
# (0, 1.2)

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)
from scipy import interpolate
import numpy as np
# tn=125
tlist = np.linspace(0, 124, 2490)
fig, ax = plt.subplots(figsize=(15,10))
ax.plot (tlist, C0_80, linewidth = 2, label="F=0.8 кВ/см")
ax.plot (tlist, C0_50, linewidth = 2, label="F=0.5 кВ/см")
#ax1.set_ylabel('$|Psi(t=0)|^2$')
ax.plot (tlist, C0_40, linewidth = 2, label="F=0.4 кВ/см")
ax.plot (tlist, C0_30, linewidth = 2, label="F=0.3 кВ/см")
ax.plot (tlist, C0_20, linewidth = 2, label="F=0.2 кВ/см")
legend = ax.legend(loc='upper right', shadow=False, fontsize='x-large')
ax.set_xlabel('dt/T', rotation=0, fontsize=25, labelpad=20)
ax.set_ylabel('$|C_1|^2$', rotation=0, fontsize=25, labelpad=20)
ax.yaxis.set_label_coords(-0.08, 0.98)
ax.xaxis.set_label_coords(1.05, 0.03)
ax.set_xticks(np.linspace(0, 120, 12+1))
ax.set_yticks(np.linspace(0, 1., 10+1))
ax.set_ylim(bottom=0, top=1.)
ax.set_xlim(left=0, right=124)
#ax.xaxis.set_major_locator(MultipleLocator(25))
#ax.xaxis.set_major_formatter(FormatStrFormatter('%d'))
ax.tick_params(labelsize='xx-large')
ax.grid(color='black', linestyle='-', linewidth=0.2)
#ax.yaxis.set_label_coords(-0.5,2)
plt.show()
fig.savefig('Cnevvolute.png', dpi=170)
#plt.xlim(0, 1000)

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)
tlist = np.linspace(1, 125, tn)
fig, ax = plt.subplots(figsize=(15,10))
ax.plot (tlist, C1_80, linewidth = 2, label="F=0.8 кВ/см")
ax.plot (tlist, C1_50, linewidth = 2, label="F=0.5 кВ/см")
ax.plot (tlist, C1_40, linewidth = 2, label="F=0.4 кВ/см")
ax.plot (tlist, C1_30, linewidth = 2, label="F=0.3 кВ/см")
ax.plot (tlist, C1_20, linewidth = 2, label="F=0.2 кВ/см")
legend = ax.legend(loc='upper right', shadow=False, fontsize='x-large')
ax.set_xlabel('dt/T', rotation=0, fontsize=25, labelpad=20)
ax.set_ylabel('$|C_2|^2$', rotation=0, fontsize=25, labelpad=20)
ax.yaxis.set_label_coords(-0.08, 0.98)
ax.xaxis.set_label_coords(1.05, 0.03)
#ax.set_xticks([20, 30, 40, 50, 60, 70, 80, 90, 100])
ax.set_xticks(np.linspace(0, 120, 12+1))
ax.set_yticks(np.linspace(0, 1., 10+1))
ax.set_ylim(bottom=0, top=1.)
ax.set_xlim(left=0, right=124)
#ax.xaxis.set_major_locator(MultipleLocator(25))
#ax.xaxis.set_major_formatter(FormatStrFormatter('%d'))
ax.tick_params(labelsize='xx-large')
ax.grid(color='black', linestyle='-', linewidth=0.2)
#ax.yaxis.set_label_coords(-0.5,2)
plt.show()
fig.savefig('Cn2evvolute.png', dpi=170)
#plt.xlim(0, 1000)

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)
tlist = np.linspace(1, 125, tn)
fig, ax = plt.subplots(figsize=(15,10))
ax.plot (tlist, C1_50, linewidth = 2, color='red',linestyle='--')
ax.plot (tlist, C0_50, linewidth = 2, color='red', linestyle='-')

legend = ax.legend(loc='upper right', shadow=False, fontsize='x-large')
ax.set_xlabel('dt/T', rotation=0, fontsize=25, labelpad=20)
ax.set_ylabel('$|C_1,_2|^2$', rotation=0, fontsize=25, labelpad=20)
ax.yaxis.set_label_coords(-0.09, 0.98)
ax.xaxis.set_label_coords(1.05, 0.03)
#ax.set_xticks([20, 30, 40, 50, 60, 70, 80, 90, 100])
ax.set_xticks(np.linspace(0, 120, 12+1))
ax.set_yticks(np.linspace(0, 1., 10+1))
ax.set_ylim(bottom=0, top=1.)
ax.set_xlim(left=0, right=124)
ax.grid(color='black', linestyle='-', linewidth=0.2)
#ax.xaxis.set_major_locator(MultipleLocator(25))
#ax.xaxis.set_major_formatter(FormatStrFormatter('%d'))
ax.tick_params(labelsize='xx-large')
ax.annotate('F = 0.5 кВ/см', xy=(50, 0.75), color='red',fontsize='xx-large')
#ax.yaxis.set_label_coords(-0.5,2)
plt.show()
fig.savefig('Cn12evvolute.png', dpi=170)
#plt.xlim(0, 1000)
# Out:
# No handles with labels found to put in legend.

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)
tlist = np.linspace(1, 125, tn)
fig, ax = plt.subplots(figsize=(15,10))
ax.plot (tlist, np.asarray(C1_80)+np.asarray(C0_80), linewidth = 2, label="F=0.8 кВ/см")
ax.plot (tlist, np.asarray(C1_50)+np.asarray(C0_50), linewidth = 2, label="F=0.5 кВ/см")
ax.plot (tlist, np.asarray(C1_40)+np.asarray(C0_40), linewidth = 2, label="F=0.4 кВ/см")
ax.plot (tlist, np.asarray(C1_30)+np.asarray(C0_30), linewidth = 2, label="F=0.3 кВ/см")
ax.plot (tlist, np.asarray(C1_20)+np.asarray(C0_20), linewidth = 2, label="F=0.2 кВ/см")
legend = ax.legend(loc='lower left', shadow=False, fontsize='xx-large')
ax.set_xlabel('dt/T', rotation=0, fontsize=25, labelpad=20)
ax.set_ylabel('$P_{loc}$', rotation=0, fontsize=25, labelpad=20)
ax.yaxis.set_label_coords(-0.08, 0.98)
ax.xaxis.set_label_coords(1.05, 0.03)
ax.set_xticks(np.linspace(0, 120, 12+1))
ax.set_yticks(np.linspace(0, 1., 10+1))
ax.set_ylim(bottom=0, top=1.)
ax.set_xlim(left=0, right=124)
ax.grid(color='black', linestyle='-', linewidth=0.2)
ax.set_ylim(bottom=0, top=1)
ax.set_xlim(left=0, right=125)
ax.tick_params(labelsize='xx-large')
#ax.yaxis.set_label_coords(-0.5,2)
plt.show()

fig.savefig('Plocevvolute.png', dpi=170)
#plt.xlim(0, 1000)

# %%
print('$P_l$')
# Out:
# $P_l$

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)
tlist = np.linspace(1, 125, tn)
fig, ax = plt.subplots(figsize=(15,10))
ax.plot (tlist, C0_80, linewidth = 2, label="F=0.8 кВ/см")
ax.plot (tlist, C0_20, linewidth = 2, label="F=0.2 кВ/см")
legend = ax.legend(loc='upper right', shadow=False, fontsize='xx-large')
ax.set_xlabel('dt/T', rotation=0, fontsize=25, labelpad=20)
ax.set_ylabel('$|C_1|^2$', rotation=0, fontsize=25, labelpad=20)
ax.yaxis.set_label_coords(-0.08, 0.98)
ax.xaxis.set_label_coords(1.05, 0.03)
#ax.set_xticks([20, 30, 40, 50, 60, 70, 80, 90, 100])
ax.set_ylim(bottom=0, top=1)
ax.set_xlim(left=0, right=125)
ax.xaxis.set_major_locator(MultipleLocator(25))
ax.xaxis.set_major_formatter(FormatStrFormatter('%d'))
ax.tick_params(labelsize='xx-large')
#ax.yaxis.set_label_coords(-0.5,2)
plt.show()

fig.savefig('Cnevvolute2.png', dpi=170)
#plt.xlim(0, 1000)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-101-f1698eaf00e5> in <module>
# ----> 1 print('P'+lower('loc'))
#
# NameError: name 'lower' is not defined

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)
tn=2500
tlist = np.linspace(1, 125, tn)
fig, ax = plt.subplots(figsize=(15,10))
ax.plot (tlist, C1_80, linewidth = 2, label="F=0.8 кВ/см")
ax.plot (tlist, C1_20, linewidth = 2, label="F=0.2 кВ/см")
legend = ax.legend(loc='upper right', shadow=False, fontsize='xx-large')
ax.set_xlabel('dt/T', rotation=0, fontsize=25, labelpad=20)
ax.set_ylabel('$|C_2|^2$', rotation=0, fontsize=25, labelpad=20)
ax.yaxis.set_label_coords(-0.08, 0.98)
ax.xaxis.set_label_coords(1.05, 0.03)
#ax.set_xticks([20, 30, 40, 50, 60, 70, 80, 90, 100])
ax.set_ylim(bottom=0, top=1)
ax.set_xlim(left=0, right=125)
ax.xaxis.set_major_locator(MultipleLocator(25))
ax.xaxis.set_major_formatter(FormatStrFormatter('%d'))
ax.tick_params(labelsize='xx-large')
plt.plot(X, Y)
  
ax = plt.gca()
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('center')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

#ax.yaxis.set_label_coords(-0.5,2)
plt.show()

fig.savefig('Cn2evvolute2.png', dpi=170)
#plt.xlim(0, 1000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-9a86e15229bf> in <module>
#       5 tlist = np.linspace(1, 125, tn)
#       6 fig, ax = plt.subplots(figsize=(15,10))
# ----> 7 ax.plot (tlist, C1_80, linewidth = 2, label="F=0.8 кВ/см")
#       8 ax.plot (tlist, C1_20, linewidth = 2, label="F=0.2 кВ/см")
#       9 legend = ax.legend(loc='upper right', shadow=False, fontsize='xx-large')
#
# NameError: name 'C1_80' is not defined
